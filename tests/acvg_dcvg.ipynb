# %%
from corrosions import AcvgDcvg

# %%
acvg_dcvg = AcvgDcvg(
    file_or_dir=r"D:\Projects\corrosions\tests\acvg-dcvg-jonggol-cimanggis-16.xlsx",
    verbose=True,
    overwrite=True,
)

# %%
acvg_dcvg.normalize()
# Out:
# Processing file: D:\Projects\corrosions\tests\acvg-dcvg-jonggol-cimanggis-16.xlsx
# || Processing sheet: Sheet1 OK!

# %%
acvg_dcvg.results
# Out:
# [{'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-jonggol-cimanggis-16-sheet1.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\json\\acvg-dcvg-jonggol-cimanggis-16-sheet1.json',
#   'sheet': 'Sheet1'}]

# %%
acvg_dcvg
