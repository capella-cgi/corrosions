# %%
from corrosions import AcvgDcvg

# %%
acvg_dcvg = AcvgDcvg(
    file_or_dir=r"D:\Projects\corrosions\tests\acvg_dcvg",
    verbose=True,
    overwrite=True,
)

# %%
acvg_dcvg.normalize()

# %%
acvg_dcvg.results
# Out:
# [{'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-bak-valve-tiara-tj-duren-mall-taman-anggrek-10-jakarta-sheet1.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\json\\acvg-dcvg-bak-valve-tiara-tj-duren-mall-taman-anggrek-10-jakarta-sheet1.json',
#   'sheet': 'Sheet1'},
#  {'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-bekasi-narogong-kedep-16-bogor-sheet1.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\json\\acvg-dcvg-bekasi-narogong-kedep-16-bogor-sheet1.json',
#   'sheet': 'Sheet1'},
#  {'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-bv-pltg-pt-arida-ii-6-sheet1.xlsx',
# ...
