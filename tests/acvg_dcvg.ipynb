# %%
from corrosions import AcvgDcvg

# %%
acvg_dcvg = AcvgDcvg(
    file_or_dir=r"D:\Projects\corrosions\tests\acvg_dcvg",
    verbose=True,
    overwrite=True,
)

# %%
acvg_dcvg.normalize()
# Out:
# Processing file: D:\Projects\corrosions\tests\acvg_dcvg\acvg-dcvg-bv-pltg-pt-arida-ii-6.xlsx
# || Processing sheet: Sheet1 OK!
# Processing file: D:\Projects\corrosions\tests\acvg_dcvg\acvg-dcvg-cawang-ahmad-yani-12.xlsx
# || Processing sheet: Sheet1 OK!
# Processing file: D:\Projects\corrosions\tests\acvg_dcvg\acvg-dcvg-cibeet-offtake-surya-cipta-24.xlsx
# || Processing sheet: Sheet1 OK!
# Processing file: D:\Projects\corrosions\tests\acvg_dcvg\acvg-dcvg-jiep-rusun-klender-4.xlsx
# || Processing sheet: Sheet1 OK!
# Processing file: D:\Projects\corrosions\tests\acvg_dcvg\acvg-dcvg-jiep-rusun-klender-6.xlsx
# || Processing sheet: Sheet1 OK!
# Processing file: D:\Projects\corrosions\tests\acvg_dcvg\acvg-dcvg-jonggol-cimanggis-16.xlsx
# || Processing sheet: Sheet1 OK!
# Processing file: D:\Projects\corrosions\tests\acvg_dcvg\acvg-dcvg-ms-batu-ceper-st-bitung-16.xlsx
# || Processing sheet: Sheet1 OK!
# ...

# %%
acvg_dcvg.results
# Out:
# [{'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-bv-pltg-pt-arida-ii-6-sheet1.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\json\\acvg-dcvg-bv-pltg-pt-arida-ii-6-sheet1.json',
#   'sheet': 'Sheet1'},
#  {'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-cawang-ahmad-yani-12-sheet1.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\json\\acvg-dcvg-cawang-ahmad-yani-12-sheet1.json',
#   'sheet': 'Sheet1'},
#  {'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-cibeet-offtake-surya-cipta-24-sheet1.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\json\\acvg-dcvg-cibeet-offtake-surya-cipta-24-sheet1.json',
#   'sheet': 'Sheet1'},
#  {'success': True,
# ...

# %%
acvg_dcvg.results
# Out:
# [{'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-bv-pltg-pt-arida-ii-6-sheet1.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\json\\acvg-dcvg-bv-pltg-pt-arida-ii-6-sheet1.json',
#   'sheet': 'Sheet1'},
#  {'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-cawang-ahmad-yani-12-sheet1.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\json\\acvg-dcvg-cawang-ahmad-yani-12-sheet1.json',
#   'sheet': 'Sheet1'},
#  {'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\excel\\acvg-dcvg-cibeet-offtake-surya-cipta-24-sheet1.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\acvg_dcvg\\json\\acvg-dcvg-cibeet-offtake-surya-cipta-24-sheet1.json',
#   'sheet': 'Sheet1'},
#  {'success': True,
# ...
