# %%
from corrosions import CIPS

# %%
cips = CIPS(
    file_or_dir=r"D:\Projects\extract-kml\DATA IDDA24\Data CIPS",
    verbose=True,
)

# %%
cips.normalize()
# Out:
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data CIPS\CIPS BGR 16 inch (Jonggol - Cimanggis 9.95 km).xlsx
# || Processing sheet: Survey Data OK!
# || Processing sheet: Sheet1 ‼️NOT OK!
# || Processing sheet: DCP Data ‼️NOT OK!
# || Processing sheet: Survey Info ‼️NOT OK!
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data CIPS\CIPS BKS 10 inch (Unisma - Kalimalang 4.9 km).xlsx
# || Processing sheet: Calc OK!
# || Processing sheet: Sheet1 OK!
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data CIPS\CIPS BKS 10 inch (Unisma - Pd Ungu 8.55 km).xlsx
# || Processing sheet: Calc OK!
# || Processing sheet: Sheet1 OK!
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data CIPS\CIPS BKS 16 inch (Unisma - Pd Ungu 8.7 km).xlsx
# || Processing sheet: Survey Data OK!
# || Processing sheet: DCP Data ‼️NOT OK!
# || Processing sheet: Survey Info ‼️NOT OK!
# || Processing sheet: Sheet1 ‼️NOT OK!
# ...

# %%
cips.results
# Out:
# [{'success': True,
#   'message': 'File already normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\excel\\cips-cips-bgr-16-inch-jonggol-cimanggis-9-95-km-survey-data.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\json\\cips-cips-bgr-16-inch-jonggol-cimanggis-9-95-km-survey-data.json',
#   'sheet': 'Survey Data'},
#  {'success': False,
#   'message': "Sheet: Sheet1. Missing columns: ['Data No', 'Latitude', 'Longitude', 'DCP/Feature/DCVG Anomaly', 'Voltage/Off Voltage']",
#   'excel': None,
#   'json': None,
#   'sheet': 'Sheet1'},
#  {'success': False,
#   'message': "Sheet: DCP Data. Missing columns: ['DCP/Feature/DCVG Anomaly', 'Voltage/Off Voltage']",
#   'excel': None,
#   'json': None,
#   'sheet': 'DCP Data'},
#  {'success': False,
#   'message': "Sheet: Survey Info. Missing columns: ['Data No', 'Latitude', 'Longitude', 'DCP/Feature/DCVG Anomaly', 'Voltage/Off Voltage']",
#   'excel': None,
#   'json': None,
#   'sheet': 'Survey Info'},
# ...
