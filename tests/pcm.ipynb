# %%
from corrosions import PCM
import pandas as pd

# %%
pcm = PCM(
    file_or_dir=r"D:\Projects\extract-kml\DATA IDDA24\Data PCM",
    overwrite=True,
    verbose=True,
)

# %%
pcm.normalize()
# Out:
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data PCM\PCM BGR 16 inch (Jonggol - Cimanggis 9.95 km).xlsx
# || Processing sheet: Sequential File OK!
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data PCM\PCM BKS 10 inch (Unisma - Inspeksi Kalimalang 4.9 km).xlsx
# || Processing sheet: Sequential Files OK!
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data PCM\PCM BKS 10 inch (Unisma - Pd Ungu 8.55 km).xlsx
# || Processing sheet: Sequential Files OK!
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data PCM\PCM BKS 16 inch (Unisma - Pd Ungu 8.7 km).xlsx
# || Processing sheet: Sequential Files OK!
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data PCM\PCM BKS 24 inch (Rawa Maju - Tegal Gede - Offtake Deltamas).xlsx
# || Processing sheet: Sheet1 OK!
# Processing file: D:\Projects\extract-kml\DATA IDDA24\Data PCM\PCM CLG 16 inch Anyer - Cilegon.xlsx
# || Processing sheet: Anyer - Cilegon OK!
# ...

# %%
pcm.results
# Out:
# [{'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\pcm\\excel\\pcm-bgr-16-inch-jonggol-cimanggis-9-95-km-sequential-file.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\pcm\\json\\pcm-bgr-16-inch-jonggol-cimanggis-9-95-km-sequential-file.json',
#   'sheet': 'Sequential File'},
#  {'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\pcm\\excel\\pcm-bks-10-inch-unisma-inspeksi-kalimalang-4-9-km-sequential-files.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\pcm\\json\\pcm-bks-10-inch-unisma-inspeksi-kalimalang-4-9-km-sequential-files.json',
#   'sheet': 'Sequential Files'},
#  {'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\pcm\\excel\\pcm-bks-10-inch-unisma-pd-ungu-8-55-km-sequential-files.xlsx',
# ...

# %%
faileds = []
for result in pcm.results:
    if not result['success']:
        faileds.append(result)

# %%
faileds
# Out:
# []

# %%
df = pd.DataFrame(faileds)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
