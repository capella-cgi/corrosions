# %%
from corrosions import PCM
import pandas as pd

# %%
# dir = r"D:\Projects\corrosions\tests\normalize\pcm\excel"
dir = r"D:\Projects\extract-kml\DATA IDDA24\Data PCM"

# %%
pcm = PCM(
    file_or_dir=r"D:\Data\PCM\PCM 60 CRB STD Gempol - STD Garawangi.xlsx",
    overwrite=True,
    verbose=True,
)

# %%
pcm.normalize()

# %%
pcm.results
# Out:
# [{'success': True,
#   'message': 'File normalized',
#   'excel': 'D:\\Projects\\corrosions\\tests\\normalize\\pcm\\excel\\pcm-60-crb-std-gempol-std-garawangi-data.xlsx',
#   'json': 'D:\\Projects\\corrosions\\tests\\normalize\\pcm\\json\\pcm-60-crb-std-gempol-std-garawangi-data.json',
#   'sheet': 'Data'}]

# %%
faileds = []
for result in pcm.results:
    if not result['success']:
        faileds.append(result)

# %%
faileds

# %%
df = pd.DataFrame(faileds)

# %%
df
